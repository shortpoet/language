# %%
# import inside your project
from nutritionix.nutritionix import NutritionixClient
nutritionix = NutritionixClient(
    application_id='5259cb50',
    api_key='a4385f0492ddf5afc1f7ea09c928d042',
    debug=True, # defaults to False
)

# %%
import requests
import json
import logging
import urllib
from pprint import pprint
import pandas as pd
from datetime import datetime as dt

import os

import pymongo
from bson.json_util import dumps, loads
from bson.objectid import ObjectId

# %%
app_id='5259cb50'
api_key='c3f7e1ac13fcbc656d06c33a26bdc599'

headers = {
    'X-APP-ID': app_id,
    'X-APP-KEY': api_key
}

# params = {
#     'q' = '',
#     'limit' = 1,
#     'offset' = 0,
#     'type' = ,
#     'id' = ,
#     'gram_weight' = ,
# }

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/utils/nutrients"    #   gets the superset of poss vals in full_nutrients array; no params
url = base_url + endpoint

r = requests.get(url, headers=headers)

# %%
j = r.json()
for i in j:
    pprint(i)
# Out:
# {'api_name': 'nf_protein',
#  'attr_id': 203,
#  'fda_daily_value': 50,
#  'name': 'nf_protein',
#  'unit': 'g',
#  'usda_nutr_desc': 'Protein',
#  'usda_sr_order': 600,
#  'usda_tag': 'PROCNT'}
# {'api_name': 'nf_total_fat',
#  'attr_id': 204,
#  'fda_daily_value': 65,
#  'name': 'nf_total_fat',
#  'unit': 'g',
#  'usda_nutr_desc': 'Total lipid (fat)',
#  'usda_sr_order': 800,
#  'usda_tag': 'FAT'}
# {'api_name': 'nf_total_carbohydrate',
#  'attr_id': 205,
#  'fda_daily_value': 300,
#  'name': 'nf_total_carbohydrate',
#  'unit': 'g',
#  'usda_nutr_desc': 'Carbohydrate, by difference',
#  'usda_sr_order': 1100,
#  'usda_tag': 'CHOCDF'}
# {'api_name': 'nf_ash',
#  'attr_id': 207,
#  'fda_daily_value': None,
#  'name': 'nf_ash',
#  'unit': 'g',
#  'usda_nutr_desc': 'Ash',
#  'usda_sr_order': 1000,
#  'usda_tag': 'ASH'}
# {'api_name': 'nf_calories',
#  'attr_id': 208,
#  'fda_daily_value': 2000,
#  'name': 'nf_calories',
#  'unit': 'kcal',
#  'usda_nutr_desc': 'Energy',
#  'usda_sr_order': 300,
#  'usda_tag': 'ENERC_KCAL'}
# {'api_name': 'nf_starch',
#  'attr_id': 209,
#  'fda_daily_value': None,
#  'name': 'nf_starch',
#  'unit': 'g',
#  'usda_nutr_desc': 'Starch',
#  'usda_sr_order': 2200,
#  'usda_tag': 'STARCH'}
# {'api_name': 'nf_sucs',
#  'attr_id': 210,
#  'fda_daily_value': None,
#  'name': 'nf_sucs',
#  'unit': 'g',
#  'usda_nutr_desc': 'Sucrose',
#  'usda_sr_order': 1600,
#  'usda_tag': 'SUCS'}
# {'api_name': 'nf_glus',
#  'attr_id': 211,
#  'fda_daily_value': None,
#  'name': 'nf_glus',
#  'unit': 'g',
#  'usda_nutr_desc': 'Glucose (dextrose)',
#  'usda_sr_order': 1700,
#  'usda_tag': 'GLUS'}
# {'api_name': 'nf_frus',
#  'attr_id': 212,
#  'fda_daily_value': None,
#  'name': 'nf_frus',
#  'unit': 'g',
#  'usda_nutr_desc': 'Fructose',
#  'usda_sr_order': 1800,
#  'usda_tag': 'FRUS'}
# {'api_name': 'nf_lacs',
#  'attr_id': 213,
#  'fda_daily_value': None,
#  'name': 'nf_lacs',
#  'unit': 'g',
#  'usda_nutr_desc': 'Lactose',
#  'usda_sr_order': 1900,
#  'usda_tag': 'LACS'}
# {'api_name': 'nf_mals',
#  'attr_id': 214,
#  'fda_daily_value': None,
#  'name': 'nf_mals',
#  'unit': 'g',
#  'usda_nutr_desc': 'Maltose',
#  'usda_sr_order': 2000,
#  'usda_tag': 'MALS'}
# {'api_name': 'nf_alc',
#  'attr_id': 221,
#  'fda_daily_value': None,
#  'name': 'nf_alc',
#  'unit': 'g',
#  'usda_nutr_desc': 'Alcohol, ethyl',
#  'usda_sr_order': 18200,
#  'usda_tag': 'ALC'}
# {'api_name': 'nf_water',
#  'attr_id': 255,
#  'fda_daily_value': None,
#  'name': 'nf_water',
#  'unit': 'g',
#  'usda_nutr_desc': 'Water',
#  'usda_sr_order': 100,
#  'usda_tag': 'WATER'}
# {'api_name': None,
#  'attr_id': 257,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Adjusted Protein',
#  'usda_sr_order': 700,
#  'usda_tag': None}
# {'api_name': 'nf_caffn',
#  'attr_id': 262,
#  'fda_daily_value': None,
#  'name': 'nf_caffn',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Caffeine',
#  'usda_sr_order': 18300,
#  'usda_tag': 'CAFFN'}
# {'api_name': 'nf_thebrn',
#  'attr_id': 263,
#  'fda_daily_value': None,
#  'name': 'nf_thebrn',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Theobromine',
#  'usda_sr_order': 18400,
#  'usda_tag': 'THEBRN'}
# {'api_name': 'nf_enerc_kj',
#  'attr_id': 268,
#  'fda_daily_value': None,
#  'name': 'nf_enerc_kj',
#  'unit': 'kJ',
#  'usda_nutr_desc': 'Energy',
#  'usda_sr_order': 400,
#  'usda_tag': 'ENERC_KJ'}
# {'api_name': 'nf_sugars',
#  'attr_id': 269,
#  'fda_daily_value': None,
#  'name': 'nf_sugars',
#  'unit': 'g',
#  'usda_nutr_desc': 'Sugars, total',
#  'usda_sr_order': 1500,
#  'usda_tag': 'SUGAR'}
# {'api_name': 'nf_gals',
#  'attr_id': 287,
#  'fda_daily_value': None,
#  'name': 'nf_gals',
#  'unit': 'g',
#  'usda_nutr_desc': 'Galactose',
#  'usda_sr_order': 2100,
#  'usda_tag': 'GALS'}
# {'api_name': 'nf_dietary_fiber',
#  'attr_id': 291,
#  'fda_daily_value': 25,
#  'name': 'nf_dietary_fiber',
#  'unit': 'g',
#  'usda_nutr_desc': 'Fiber, total dietary',
#  'usda_sr_order': 1200,
#  'usda_tag': 'FIBTG'}
# {'api_name': 'nf_calcium_dv',
#  'attr_id': 301,
#  'fda_daily_value': 1000,
#  'name': 'nf_calcium_dv',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Calcium, Ca',
#  'usda_sr_order': 5300,
#  'usda_tag': 'CA'}
# {'api_name': 'nf_iron_dv',
#  'attr_id': 303,
#  'fda_daily_value': 18,
#  'name': 'nf_iron_dv',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Iron, Fe',
#  'usda_sr_order': 5400,
#  'usda_tag': 'FE'}
# {'api_name': 'nf_mg',
#  'attr_id': 304,
#  'fda_daily_value': None,
#  'name': 'nf_mg',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Magnesium, Mg',
#  'usda_sr_order': 5500,
#  'usda_tag': 'MG'}
# {'api_name': 'nf_p',
#  'attr_id': 305,
#  'fda_daily_value': 1000,
#  'name': 'nf_p',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Phosphorus, P',
#  'usda_sr_order': 5600,
#  'usda_tag': 'P'}
# {'api_name': 'nf_potassium',
#  'attr_id': 306,
#  'fda_daily_value': 3500,
#  'name': 'nf_potassium',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Potassium, K',
#  'usda_sr_order': 5700,
#  'usda_tag': 'K'}
# {'api_name': 'nf_sodium',
#  'attr_id': 307,
#  'fda_daily_value': 2400,
#  'name': 'nf_sodium',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Sodium, Na',
#  'usda_sr_order': 5800,
#  'usda_tag': 'NA'}
# {'api_name': 'nf_zn',
#  'attr_id': 309,
#  'fda_daily_value': None,
#  'name': 'nf_zn',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Zinc, Zn',
#  'usda_sr_order': 5900,
#  'usda_tag': 'ZN'}
# {'api_name': 'nf_cu',
#  'attr_id': 312,
#  'fda_daily_value': None,
#  'name': 'nf_cu',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Copper, Cu',
#  'usda_sr_order': 6000,
#  'usda_tag': 'CU'}
# {'api_name': 'nf_fld',
#  'attr_id': 313,
#  'fda_daily_value': None,
#  'name': 'nf_fld',
#  'unit': 'µg',
#  'usda_nutr_desc': 'Fluoride, F',
#  'usda_sr_order': 6240,
#  'usda_tag': 'FLD'}
# {'api_name': 'nf_mn',
#  'attr_id': 315,
#  'fda_daily_value': None,
#  'name': 'nf_mn',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Manganese, Mn',
#  'usda_sr_order': 6100,
#  'usda_tag': 'MN'}
# {'api_name': 'nf_se',
#  'attr_id': 317,
#  'fda_daily_value': None,
#  'name': 'nf_se',
#  'unit': 'µg',
#  'usda_nutr_desc': 'Selenium, Se',
#  'usda_sr_order': 6200,
#  'usda_tag': 'SE'}
# {'api_name': 'nf_vitamin_a_dv',
#  'attr_id': 318,
#  'fda_daily_value': 5000,
#  'name': 'nf_vitamin_a_dv',
#  'unit': 'IU',
#  'usda_nutr_desc': 'Vitamin A, IU',
#  'usda_sr_order': 7500,
#  'usda_tag': 'VITA_IU'}
# {'api_name': 'nf_retol',
#  'attr_id': 319,
#  'fda_daily_value': None,
#  'name': 'nf_retol',
#  'unit': 'µg',
#  'usda_nutr_desc': 'Retinol',
#  'usda_sr_order': 7430,
#  'usda_tag': 'RETOL'}
# {'api_name': None,
#  'attr_id': 320,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin A, RAE',
#  'usda_sr_order': 7420,
#  'usda_tag': 'VITA_RAE'}
# {'api_name': None,
#  'attr_id': 321,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Carotene, beta',
#  'usda_sr_order': 7440,
#  'usda_tag': 'CARTB'}
# {'api_name': None,
#  'attr_id': 322,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Carotene, alpha',
#  'usda_sr_order': 7450,
#  'usda_tag': 'CARTA'}
# {'api_name': None,
#  'attr_id': 323,
#  'fda_daily_value': 30,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Vitamin E (alpha-tocopherol)',
#  'usda_sr_order': 7900,
#  'usda_tag': 'TOCPHA'}
# {'api_name': None,
#  'attr_id': 324,
#  'fda_daily_value': 400,
#  'name': None,
#  'unit': 'IU',
#  'usda_nutr_desc': 'Vitamin D',
#  'usda_sr_order': 8750,
#  'usda_tag': 'VITD'}
# {'api_name': None,
#  'attr_id': 325,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin D2 (ergocalciferol)',
#  'usda_sr_order': 8710,
#  'usda_tag': 'ERGCAL'}
# {'api_name': None,
#  'attr_id': 326,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin D3 (cholecalciferol)',
#  'usda_sr_order': 8720,
#  'usda_tag': 'CHOCAL'}
# {'api_name': None,
#  'attr_id': 328,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin D (D2 + D3)',
#  'usda_sr_order': 8700,
#  'usda_tag': 'VITD'}
# {'api_name': None,
#  'attr_id': 334,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Cryptoxanthin, beta',
#  'usda_sr_order': 7460,
#  'usda_tag': 'CRYPX'}
# {'api_name': None,
#  'attr_id': 337,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Lycopene',
#  'usda_sr_order': 7530,
#  'usda_tag': 'LYCPN'}
# {'api_name': None,
#  'attr_id': 338,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Lutein + zeaxanthin',
#  'usda_sr_order': 7560,
#  'usda_tag': 'LUT+ZEA'}
# {'api_name': None,
#  'attr_id': 341,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Tocopherol, beta',
#  'usda_sr_order': 8000,
#  'usda_tag': 'TOCPHB'}
# {'api_name': None,
#  'attr_id': 342,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Tocopherol, gamma',
#  'usda_sr_order': 8100,
#  'usda_tag': 'TOCPHG'}
# {'api_name': None,
#  'attr_id': 343,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Tocopherol, delta',
#  'usda_sr_order': 8200,
#  'usda_tag': 'TOCPHD'}
# {'api_name': 'nf_vitamin_c_dv',
#  'attr_id': 401,
#  'fda_daily_value': 60,
#  'name': 'nf_vitamin_c_dv',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Vitamin C, total ascorbic acid',
#  'usda_sr_order': 6300,
#  'usda_tag': 'VITC'}
# {'api_name': None,
#  'attr_id': 404,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Thiamin',
#  'usda_sr_order': 6400,
#  'usda_tag': 'THIA'}
# {'api_name': None,
#  'attr_id': 405,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Riboflavin',
#  'usda_sr_order': 6500,
#  'usda_tag': 'RIBF'}
# {'api_name': None,
#  'attr_id': 406,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Niacin',
#  'usda_sr_order': 6600,
#  'usda_tag': 'NIA'}
# {'api_name': None,
#  'attr_id': 410,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Pantothenic acid',
#  'usda_sr_order': 6700,
#  'usda_tag': 'PANTAC'}
# {'api_name': None,
#  'attr_id': 415,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Vitamin B-6',
#  'usda_sr_order': 6800,
#  'usda_tag': 'VITB6A'}
# {'api_name': None,
#  'attr_id': 417,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Folate, total',
#  'usda_sr_order': 6900,
#  'usda_tag': 'FOL'}
# {'api_name': None,
#  'attr_id': 418,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin B-12',
#  'usda_sr_order': 7300,
#  'usda_tag': 'VITB12'}
# {'api_name': None,
#  'attr_id': 421,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Choline, total',
#  'usda_sr_order': 7220,
#  'usda_tag': 'CHOLN'}
# {'api_name': None,
#  'attr_id': 428,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Menaquinone-4',
#  'usda_sr_order': 8950,
#  'usda_tag': 'MK4'}
# {'api_name': None,
#  'attr_id': 429,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Dihydrophylloquinone',
#  'usda_sr_order': 8900,
#  'usda_tag': 'VITK1D'}
# {'api_name': None,
#  'attr_id': 430,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin K (phylloquinone)',
#  'usda_sr_order': 8800,
#  'usda_tag': 'VITK1'}
# {'api_name': None,
#  'attr_id': 431,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Folic acid',
#  'usda_sr_order': 7000,
#  'usda_tag': 'FOLAC'}
# {'api_name': None,
#  'attr_id': 432,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Folate, food',
#  'usda_sr_order': 7100,
#  'usda_tag': 'FOLFD'}
# {'api_name': None,
#  'attr_id': 435,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Folate, DFE',
#  'usda_sr_order': 7200,
#  'usda_tag': 'FOLDFE'}
# {'api_name': None,
#  'attr_id': 454,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Betaine',
#  'usda_sr_order': 7270,
#  'usda_tag': 'BETN'}
# {'api_name': None,
#  'attr_id': 501,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Tryptophan',
#  'usda_sr_order': 16300,
#  'usda_tag': 'TRP_G'}
# {'api_name': None,
#  'attr_id': 502,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Threonine',
#  'usda_sr_order': 16400,
#  'usda_tag': 'THR_G'}
# {'api_name': None,
#  'attr_id': 503,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Isoleucine',
#  'usda_sr_order': 16500,
#  'usda_tag': 'ILE_G'}
# {'api_name': None,
#  'attr_id': 504,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Leucine',
#  'usda_sr_order': 16600,
#  'usda_tag': 'LEU_G'}
# {'api_name': None,
#  'attr_id': 505,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Lysine',
#  'usda_sr_order': 16700,
#  'usda_tag': 'LYS_G'}
# {'api_name': None,
#  'attr_id': 506,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Methionine',
#  'usda_sr_order': 16800,
#  'usda_tag': 'MET_G'}
# {'api_name': None,
#  'attr_id': 507,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Cystine',
#  'usda_sr_order': 16900,
#  'usda_tag': 'CYS_G'}
# {'api_name': None,
#  'attr_id': 508,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Phenylalanine',
#  'usda_sr_order': 17000,
#  'usda_tag': 'PHE_G'}
# {'api_name': None,
#  'attr_id': 509,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Tyrosine',
#  'usda_sr_order': 17100,
#  'usda_tag': 'TYR_G'}
# {'api_name': None,
#  'attr_id': 510,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Valine',
#  'usda_sr_order': 17200,
#  'usda_tag': 'VAL_G'}
# {'api_name': None,
#  'attr_id': 511,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Arginine',
#  'usda_sr_order': 17300,
#  'usda_tag': 'ARG_G'}
# {'api_name': None,
#  'attr_id': 512,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Histidine',
#  'usda_sr_order': 17400,
#  'usda_tag': 'HISTN_G'}
# {'api_name': None,
#  'attr_id': 513,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Alanine',
#  'usda_sr_order': 17500,
#  'usda_tag': 'ALA_G'}
# {'api_name': None,
#  'attr_id': 514,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Aspartic acid',
#  'usda_sr_order': 17600,
#  'usda_tag': 'ASP_G'}
# {'api_name': None,
#  'attr_id': 515,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Glutamic acid',
#  'usda_sr_order': 17700,
#  'usda_tag': 'GLU_G'}
# {'api_name': None,
#  'attr_id': 516,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Glycine',
#  'usda_sr_order': 17800,
#  'usda_tag': 'GLY_G'}
# {'api_name': None,
#  'attr_id': 517,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Proline',
#  'usda_sr_order': 17900,
#  'usda_tag': 'PRO_G'}
# {'api_name': None,
#  'attr_id': 518,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Serine',
#  'usda_sr_order': 18000,
#  'usda_tag': 'SER_G'}
# {'api_name': None,
#  'attr_id': 521,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Hydroxyproline',
#  'usda_sr_order': 18100,
#  'usda_tag': 'HYP'}
# {'api_name': None,
#  'attr_id': 539,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Sugars, added',
#  'usda_sr_order': None,
#  'usda_tag': 'SUGAR_ADD'}
# {'api_name': None,
#  'attr_id': 573,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Vitamin E, added',
#  'usda_sr_order': 7920,
#  'usda_tag': None}
# {'api_name': None,
#  'attr_id': 578,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'µg',
#  'usda_nutr_desc': 'Vitamin B-12, added',
#  'usda_sr_order': 7340,
#  'usda_tag': None}
# {'api_name': 'nf_cholesterol',
#  'attr_id': 601,
#  'fda_daily_value': 300,
#  'name': 'nf_cholesterol',
#  'unit': 'mg',
#  'usda_nutr_desc': 'Cholesterol',
#  'usda_sr_order': 15700,
#  'usda_tag': 'CHOLE'}
# {'api_name': 'nf_trans_fatty_acid',
#  'attr_id': 605,
#  'fda_daily_value': None,
#  'name': 'nf_trans_fatty_acid',
#  'unit': 'g',
#  'usda_nutr_desc': 'Fatty acids, total trans',
#  'usda_sr_order': 15400,
#  'usda_tag': 'FATRN'}
# {'api_name': 'nf_saturated_fat',
#  'attr_id': 606,
#  'fda_daily_value': 20,
#  'name': 'nf_saturated_fat',
#  'unit': 'g',
#  'usda_nutr_desc': 'Fatty acids, total saturated',
#  'usda_sr_order': 9700,
#  'usda_tag': 'FASAT'}
# {'api_name': None,
#  'attr_id': 607,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '4:0',
#  'usda_sr_order': 9800,
#  'usda_tag': 'F4D0'}
# {'api_name': None,
#  'attr_id': 608,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '6:0',
#  'usda_sr_order': 9900,
#  'usda_tag': 'F6D0'}
# {'api_name': None,
#  'attr_id': 609,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '8:0',
#  'usda_sr_order': 10000,
#  'usda_tag': 'F8D0'}
# {'api_name': None,
#  'attr_id': 610,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '10:0',
#  'usda_sr_order': 10100,
#  'usda_tag': 'F10D0'}
# {'api_name': None,
#  'attr_id': 611,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '12:0',
#  'usda_sr_order': 10300,
#  'usda_tag': 'F12D0'}
# {'api_name': None,
#  'attr_id': 612,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '14:0',
#  'usda_sr_order': 10500,
#  'usda_tag': 'F14D0'}
# {'api_name': None,
#  'attr_id': 613,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '16:0',
#  'usda_sr_order': 10700,
#  'usda_tag': 'F16D0'}
# {'api_name': None,
#  'attr_id': 614,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:0',
#  'usda_sr_order': 10900,
#  'usda_tag': 'F18D0'}
# {'api_name': None,
#  'attr_id': 615,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:0',
#  'usda_sr_order': 11100,
#  'usda_tag': 'F20D0'}
# {'api_name': None,
#  'attr_id': 617,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:1 undifferentiated',
#  'usda_sr_order': 12100,
#  'usda_tag': 'F18D1'}
# {'api_name': None,
#  'attr_id': 618,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:2 undifferentiated',
#  'usda_sr_order': 13100,
#  'usda_tag': 'F18D2'}
# {'api_name': None,
#  'attr_id': 619,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:3 undifferentiated',
#  'usda_sr_order': 13900,
#  'usda_tag': 'F18D3'}
# {'api_name': None,
#  'attr_id': 620,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:4 undifferentiated',
#  'usda_sr_order': 14700,
#  'usda_tag': 'F20D4'}
# {'api_name': None,
#  'attr_id': 621,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:6 n-3 (DHA)',
#  'usda_sr_order': 15300,
#  'usda_tag': 'F22D6'}
# {'api_name': None,
#  'attr_id': 624,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:0',
#  'usda_sr_order': 11200,
#  'usda_tag': 'F22D0'}
# {'api_name': None,
#  'attr_id': 625,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '14:1',
#  'usda_sr_order': 11500,
#  'usda_tag': 'F14D1'}
# {'api_name': None,
#  'attr_id': 626,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '16:1 undifferentiated',
#  'usda_sr_order': 11700,
#  'usda_tag': 'F16D1'}
# {'api_name': None,
#  'attr_id': 627,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:4',
#  'usda_sr_order': 14250,
#  'usda_tag': 'F18D4'}
# {'api_name': None,
#  'attr_id': 628,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:1',
#  'usda_sr_order': 12400,
#  'usda_tag': 'F20D1'}
# {'api_name': None,
#  'attr_id': 629,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:5 n-3 (EPA)',
#  'usda_sr_order': 15000,
#  'usda_tag': 'F20D5'}
# {'api_name': None,
#  'attr_id': 630,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:1 undifferentiated',
#  'usda_sr_order': 12500,
#  'usda_tag': 'F22D1'}
# {'api_name': None,
#  'attr_id': 631,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:5 n-3 (DPA)',
#  'usda_sr_order': 15200,
#  'usda_tag': 'F22D5'}
# {'api_name': None,
#  'attr_id': 636,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Phytosterols',
#  'usda_sr_order': 15800,
#  'usda_tag': 'PHYSTR'}
# {'api_name': None,
#  'attr_id': 638,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Stigmasterol',
#  'usda_sr_order': 15900,
#  'usda_tag': 'STID7'}
# {'api_name': None,
#  'attr_id': 639,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Campesterol',
#  'usda_sr_order': 16000,
#  'usda_tag': 'CAMD5'}
# {'api_name': None,
#  'attr_id': 641,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'mg',
#  'usda_nutr_desc': 'Beta-sitosterol',
#  'usda_sr_order': 16200,
#  'usda_tag': 'SITSTR'}
# {'api_name': 'nf_monounsaturated_fat',
#  'attr_id': 645,
#  'fda_daily_value': None,
#  'name': 'nf_monounsaturated_fat',
#  'unit': 'g',
#  'usda_nutr_desc': 'Fatty acids, total monounsaturated',
#  'usda_sr_order': 11400,
#  'usda_tag': 'FAMS'}
# {'api_name': 'nf_polyunsaturated_fat',
#  'attr_id': 646,
#  'fda_daily_value': None,
#  'name': 'nf_polyunsaturated_fat',
#  'unit': 'g',
#  'usda_nutr_desc': 'Fatty acids, total polyunsaturated',
#  'usda_sr_order': 12900,
#  'usda_tag': 'FAPU'}
# {'api_name': None,
#  'attr_id': 652,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '15:0',
#  'usda_sr_order': 10600,
#  'usda_tag': 'F15D0'}
# {'api_name': None,
#  'attr_id': 653,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '17:0',
#  'usda_sr_order': 10800,
#  'usda_tag': 'F17D0'}
# {'api_name': None,
#  'attr_id': 654,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '24:0',
#  'usda_sr_order': 11300,
#  'usda_tag': 'F24D0'}
# {'api_name': None,
#  'attr_id': 662,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '16:1 t',
#  'usda_sr_order': 11900,
#  'usda_tag': 'F16D1T'}
# {'api_name': None,
#  'attr_id': 663,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:1 t',
#  'usda_sr_order': 12300,
#  'usda_tag': 'F18D1T'}
# {'api_name': None,
#  'attr_id': 664,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:1 t',
#  'usda_sr_order': 12700,
#  'usda_tag': None}
# {'api_name': None,
#  'attr_id': 665,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:2 t not further defined',
#  'usda_sr_order': 13800,
#  'usda_tag': None}
# {'api_name': None,
#  'attr_id': 666,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:2 i',
#  'usda_sr_order': 13700,
#  'usda_tag': None}
# {'api_name': None,
#  'attr_id': 669,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:2 t,t',
#  'usda_sr_order': 13600,
#  'usda_tag': 'F18D2TT'}
# {'api_name': None,
#  'attr_id': 670,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:2 CLAs',
#  'usda_sr_order': 13300,
#  'usda_tag': 'F18D2CLA'}
# {'api_name': None,
#  'attr_id': 671,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '24:1 c',
#  'usda_sr_order': 12800,
#  'usda_tag': 'F24D1C'}
# {'api_name': None,
#  'attr_id': 672,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:2 n-6 c,c',
#  'usda_sr_order': 14300,
#  'usda_tag': 'F20D2CN6'}
# {'api_name': None,
#  'attr_id': 673,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '16:1 c',
#  'usda_sr_order': 11800,
#  'usda_tag': 'F16D1C'}
# {'api_name': None,
#  'attr_id': 674,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:1 c',
#  'usda_sr_order': 12200,
#  'usda_tag': 'F18D1C'}
# {'api_name': None,
#  'attr_id': 675,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:2 n-6 c,c',
#  'usda_sr_order': 13200,
#  'usda_tag': 'F18D2CN6'}
# {'api_name': None,
#  'attr_id': 676,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:1 c',
#  'usda_sr_order': 12600,
#  'usda_tag': None}
# {'api_name': None,
#  'attr_id': 685,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:3 n-6 c,c,c',
#  'usda_sr_order': 14100,
#  'usda_tag': 'F18D3CN6'}
# {'api_name': None,
#  'attr_id': 687,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '17:1',
#  'usda_sr_order': 12000,
#  'usda_tag': 'F17D1'}
# {'api_name': None,
#  'attr_id': 689,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:3 undifferentiated',
#  'usda_sr_order': 14400,
#  'usda_tag': 'F20D3'}
# {'api_name': None,
#  'attr_id': 693,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Fatty acids, total trans-monoenoic',
#  'usda_sr_order': 15500,
#  'usda_tag': 'FATRNM'}
# {'api_name': None,
#  'attr_id': 695,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': 'Fatty acids, total trans-polyenoic',
#  'usda_sr_order': 15600,
#  'usda_tag': 'FATRNP'}
# {'api_name': None,
#  'attr_id': 696,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '13:0',
#  'usda_sr_order': 10400,
#  'usda_tag': 'F13D0'}
# {'api_name': None,
#  'attr_id': 697,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '15:1',
#  'usda_sr_order': 11600,
#  'usda_tag': 'F15D1'}
# {'api_name': None,
#  'attr_id': 851,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:3 n-3 c,c,c (ALA)',
#  'usda_sr_order': 14000,
#  'usda_tag': 'F18D3CN3'}
# {'api_name': None,
#  'attr_id': 852,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:3 n-3',
#  'usda_sr_order': 14500,
#  'usda_tag': 'F20D3N3'}
# {'api_name': None,
#  'attr_id': 853,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:3 n-6',
#  'usda_sr_order': 14600,
#  'usda_tag': 'F20D3N6'}
# {'api_name': None,
#  'attr_id': 855,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '20:4 n-6',
#  'usda_sr_order': 14900,
#  'usda_tag': 'F20D4N6'}
# {'api_name': None,
#  'attr_id': 856,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:3i',
#  'usda_sr_order': 14200,
#  'usda_tag': None}
# {'api_name': None,
#  'attr_id': 857,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '21:5',
#  'usda_sr_order': 15100,
#  'usda_tag': 'F21D5'}
# {'api_name': None,
#  'attr_id': 858,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '22:4',
#  'usda_sr_order': 15160,
#  'usda_tag': 'F22D4'}
# {'api_name': None,
#  'attr_id': 859,
#  'fda_daily_value': None,
#  'name': None,
#  'unit': 'g',
#  'usda_nutr_desc': '18:1-11t (18:1t n-7)',
#  'usda_sr_order': 12310,
#  'usda_tag': 'F18D1TN7'}

# %%
nutrient_df = pd.DataFrame(j)
# nutrient_df

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/nutrition_topics"    #   fetch a list of all nutrition topics; no params
url = base_url + endpoint

r2 = requests.get(url, headers=headers)

# %%
j2 = r2.json()
topic_df = pd.DataFrame(j2['topics'])
[name['name'] for name in j2['topics']]
# Out:
# ['Vegetarian',
#  'Vegan',
#  'Pescetarian',
#  'Atkins',
#  'South Beach',
#  'Gluten-free',
#  'Low-fat',
#  'Low-sodium',
#  'Paleo',
#  'Low Carb',
#  'Calorie Counting',
#  'Low FODMAP',
#  'Ketogenic Diet',
#  'Low Glycemic Index Diet',
#  'Mediterranean Diet',
#  'High-protein Diet',
#  'Lacto vegetarianism',
#  'Other']

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/natural/nutrients/"    #   Returns the nutrients for all foods in the posted query
url = base_url + endpoint

headers = {
    'accept': 'application/json',
    'x-app-id': app_id,
    'x-app-key': api_key,
    'x-remote-user-id': '0',
#     'Content-Type': 'application/json',
}

data = { 
    "query": "egg", 
    "num_servings": 0, 
    "line_delimited": False, 
    "use_raw_foods": False, 
    "include_subrecipe": False, 
    "lat": 0, 
    "lng": 0, 
    "meal_type": 0, 
    "use_branded_foods": False, 
    "locale": "en_US"
}

# json param replaces dumps and auto sets content-type

# data = json.dumps(data)
# r3 = requests.post(url, headers=headers, data=data)


r3 = requests.post(url, headers=headers, json=data)

# %%
j3 = r3.json()
pprint(j3)
# Out:
# {'foods': [{'alt_measures': [{'measure': 'small',
#                               'qty': 1,
#                               'seq': 7,
#                               'serving_weight': 38},
#                              {'measure': 'medium',
#                               'qty': 1,
#                               'seq': 6,
#                               'serving_weight': 44},
#                              {'measure': 'large',
#                               'qty': 1,
#                               'seq': 1,
#                               'serving_weight': 50},
#                              {'measure': 'jumbo',
#                               'qty': 1,
#                               'seq': 3,
#                               'serving_weight': 63},
#                              {'measure': 'extra large',
#                               'qty': 1,
#                               'seq': 2,
#                               'serving_weight': 56},
#                              {'measure': 'cup (4.86 large eggs)',
#                               'qty': 1,
#                               'seq': 5,
#                               'serving_weight': 243},
#                              {'measure': 'g',
#                               'qty': 100,
#                               'seq': None,
#                               'serving_weight': 100}],
#             'brand_name': None,
#             'consumed_at': '2019-02-25T02:44:38+00:00',
#             'food_name': 'egg',
#             'full_nutrients': [{'attr_id': 203, 'value': 6.28},
#                                {'attr_id': 204, 'value': 4.755},
#                                {'attr_id': 205, 'value': 0.36},
#                                {'attr_id': 207, 'value': 0.53},
#                                {'attr_id': 208, 'value': 71.5},
#                                {'attr_id': 210, 'value': 0},
#                                {'attr_id': 211, 'value': 0.185},
#                                {'attr_id': 212, 'value': 0},
#                                {'attr_id': 213, 'value': 0},
#                                {'attr_id': 214, 'value': 0},
#                                {'attr_id': 221, 'value': 0},
#                                {'attr_id': 255, 'value': 38.075},
#                                {'attr_id': 262, 'value': 0},
#                                {'attr_id': 263, 'value': 0},
#                                {'attr_id': 268, 'value': 299.5},
#                                {'attr_id': 269, 'value': 0.185},
#                                {'attr_id': 287, 'value': 0},
#                                {'attr_id': 291, 'value': 0},
#                                {'attr_id': 301, 'value': 28},
#                                {'attr_id': 303, 'value': 0.875},
#                                {'attr_id': 304, 'value': 6},
#                                {'attr_id': 305, 'value': 99},
#                                {'attr_id': 306, 'value': 69},
#                                {'attr_id': 307, 'value': 71},
#                                {'attr_id': 309, 'value': 0.645},
#                                {'attr_id': 312, 'value': 0.036},
#                                {'attr_id': 313, 'value': 0.55},
#                                {'attr_id': 315, 'value': 0.014},
#                                {'attr_id': 317, 'value': 15.35},
#                                {'attr_id': 318, 'value': 270},
#                                {'attr_id': 319, 'value': 80},
#                                {'attr_id': 320, 'value': 80},
#                                {'attr_id': 321, 'value': 0},
#                                {'attr_id': 322, 'value': 0},
#                                {'attr_id': 323, 'value': 0.525},
#                                {'attr_id': 324, 'value': 41},
#                                {'attr_id': 326, 'value': 1},
#                                {'attr_id': 328, 'value': 1},
#                                {'attr_id': 334, 'value': 4.5},
#                                {'attr_id': 337, 'value': 0},
#                                {'attr_id': 338, 'value': 251.5},
#                                {'attr_id': 341, 'value': 0.005},
#                                {'attr_id': 342, 'value': 0.25},
#                                {'attr_id': 343, 'value': 0.03},
#                                {'attr_id': 344, 'value': 0.03},
#                                {'attr_id': 345, 'value': 0},
#                                {'attr_id': 346, 'value': 0.005},
#                                {'attr_id': 347, 'value': 0},
#                                {'attr_id': 401, 'value': 0},
#                                {'attr_id': 404, 'value': 0.02},
#                                {'attr_id': 405, 'value': 0.2285},
#                                {'attr_id': 406, 'value': 0.0375},
#                                {'attr_id': 410, 'value': 0.7665},
#                                {'attr_id': 415, 'value': 0.085},
#                                {'attr_id': 417, 'value': 23.5},
#                                {'attr_id': 418, 'value': 0.445},
#                                {'attr_id': 421, 'value': 146.9},
#                                {'attr_id': 429, 'value': 0.05},
#                                {'attr_id': 430, 'value': 0.15},
#                                {'attr_id': 431, 'value': 0},
#                                {'attr_id': 432, 'value': 23.5},
#                                {'attr_id': 435, 'value': 23.5},
#                                {'attr_id': 454, 'value': 0.15},
#                                {'attr_id': 501, 'value': 0.0835},
#                                {'attr_id': 502, 'value': 0.278},
#                                {'attr_id': 503, 'value': 0.3355},
#                                {'attr_id': 504, 'value': 0.543},
#                                {'attr_id': 505, 'value': 0.456},
#                                {'attr_id': 506, 'value': 0.19},
#                                {'attr_id': 507, 'value': 0.136},
#                                {'attr_id': 508, 'value': 0.34},
#                                {'attr_id': 509, 'value': 0.2495},
#                                {'attr_id': 510, 'value': 0.429},
#                                {'attr_id': 511, 'value': 0.41},
#                                {'attr_id': 512, 'value': 0.1545},
#                                {'attr_id': 513, 'value': 0.3675},
#                                {'attr_id': 514, 'value': 0.6645},
#                                {'attr_id': 515, 'value': 0.8365},
#                                {'attr_id': 516, 'value': 0.216},
#                                {'attr_id': 517, 'value': 0.256},
#                                {'attr_id': 518, 'value': 0.4855},
#                                {'attr_id': 601, 'value': 186},
#                                {'attr_id': 605, 'value': 0.019},
#                                {'attr_id': 606, 'value': 1.563},
#                                {'attr_id': 607, 'value': 0.002},
#                                {'attr_id': 608, 'value': 0},
#                                {'attr_id': 609, 'value': 0.002},
#                                {'attr_id': 610, 'value': 0.003},
#                                {'attr_id': 611, 'value': 0},
#                                {'attr_id': 612, 'value': 0.0165},
#                                {'attr_id': 613, 'value': 1.1155},
#                                {'attr_id': 614, 'value': 0.4055},
#                                {'attr_id': 615, 'value': 0.0015},
#                                {'attr_id': 617, 'value': 1.7055},
#                                {'attr_id': 618, 'value': 0.7775},
#                                {'attr_id': 619, 'value': 0.024},
#                                {'attr_id': 620, 'value': 0.094},
#                                {'attr_id': 621, 'value': 0.029},
#                                {'attr_id': 624, 'value': 0.002},
#                                {'attr_id': 625, 'value': 0.0035},
#                                {'attr_id': 626, 'value': 0.1005},
#                                {'attr_id': 627, 'value': 0},
#                                {'attr_id': 628, 'value': 0.0135},
#                                {'attr_id': 629, 'value': 0},
#                                {'attr_id': 630, 'value': 0},
#                                {'attr_id': 631, 'value': 0.0035},
#                                {'attr_id': 645, 'value': 1.829},
#                                {'attr_id': 646, 'value': 0.9555},
#                                {'attr_id': 652, 'value': 0.004},
#                                {'attr_id': 653, 'value': 0.011},
#                                {'attr_id': 654, 'value': 0},
#                                {'attr_id': 662, 'value': 0.0015},
#                                {'attr_id': 663, 'value': 0.0115},
#                                {'attr_id': 664, 'value': 0},
#                                {'attr_id': 670, 'value': 0.006},
#                                {'attr_id': 671, 'value': 0},
#                                {'attr_id': 672, 'value': 0.009},
#                                {'attr_id': 673, 'value': 0.099},
#                                {'attr_id': 674, 'value': 1.694},
#                                {'attr_id': 675, 'value': 0.7655},
#                                {'attr_id': 676, 'value': 0},
#                                {'attr_id': 685, 'value': 0.006},
#                                {'attr_id': 687, 'value': 0.006},
#                                {'attr_id': 689, 'value': 0.0115},
#                                {'attr_id': 693, 'value': 0.013},
#                                {'attr_id': 695, 'value': 0.006},
#                                {'attr_id': 697, 'value': 0},
#                                {'attr_id': 851, 'value': 0.018},
#                                {'attr_id': 852, 'value': 0.0005},
#                                {'attr_id': 853, 'value': 0.011},
#                                {'attr_id': 858, 'value': 0.0065}],
#             'lat': 0,
#             'lng': 0,
#             'meal_type': 0,
#             'metadata': {'is_raw_food': False},
#             'ndb_no': 1123,
#             'nf_calories': 71.5,
#             'nf_cholesterol': 186,
#             'nf_dietary_fiber': 0,
#             'nf_p': 99,
#             'nf_potassium': 69,
#             'nf_protein': 6.28,
#             'nf_saturated_fat': 1.56,
#             'nf_sodium': 71,
#             'nf_sugars': 0.19,
#             'nf_total_carbohydrate': 0.36,
#             'nf_total_fat': 4.76,
#             'nix_brand_id': None,
#             'nix_brand_name': None,
#             'nix_item_id': None,
#             'nix_item_name': None,
#             'photo': {'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/775_highres.jpg',
#                       'is_user_uploaded': False,
#                       'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/775_thumb.jpg'},
#             'serving_qty': 1,
#             'serving_unit': 'large',
#             'serving_weight_grams': 50,
#             'source': 1,
#             'sub_recipe': None,
#             'tags': {'food_group': 1,
#                      'item': 'raw eggs',
#                      'measure': None,
#                      'quantity': '1.0',
#                      'tag_id': 775},
#             'upc': None}]}

# %%
logging.basicConfig(level=logging.ERROR)
# logging.debug((r3.text))

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/search/instant/"    #   Returns the nutrients for all foods in the posted query
url = base_url + endpoint

params = {
    'query': "egg",
#     'num_servings': 1,
#     'aggregate': 'mashed potatoes',
#     'use_raw_foods': False,
#     'include_subrecipe: False,
#     'timezone': "US/Eastern",
#     'consumed_at': ISO8601,
#     'lat': '',
#     'lng': '',
#     'meal_type': ,
#     'use_branded_foods': False
#     'locale': '',
}

r4 = requests.get(url, headers=headers, params=params)

# %%
j4 = r4.json()
pprint(j4)
# Out:
# {'branded': [{'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Baja Bennie',
#               'brand_type': 1,
#               'food_name': 'Baja Bennie',
#               'locale': 'en_US',
#               'nf_calories': 600,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218476dc4a553b48b19',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Chicken Breast Strips',
#               'brand_type': 1,
#               'food_name': 'Chicken Breast Strips',
#               'locale': 'en_US',
#               'nf_calories': 450,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': '32f131279da80cd653521d7d',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggo',
#               'brand_name_item_name': 'Eggo Chocolate Wafflers',
#               'brand_type': 2,
#               'food_name': 'Chocolate Wafflers',
#               'locale': 'en_US',
#               'nf_calories': 220,
#               'nix_brand_id': '51db37b2176fe9790a89859b',
#               'nix_item_id': '5593a25fd0497b881168bad3',
#               'photo': {'thumb': 'https://d1r9wva3zcpswd.cloudfront.net/5593a28238d0e0c0281af59f.jpeg'},
#               'region': 1,
#               'serving_qty': 2,
#               'serving_unit': 'waffles'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Citrus Balsamic Chicken Salad',
#               'brand_type': 1,
#               'food_name': 'Citrus Balsamic Chicken Salad',
#               'locale': 'en_US',
#               'nf_calories': 200,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218b33eefce85e43136',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Classic Western Omelette',
#               'brand_type': 1,
#               'food_name': 'Classic Western Omelette',
#               'locale': 'en_US',
#               'nf_calories': 380,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c64062181e1fdce8f3e3a3f3',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Cream of Potato with Bacon '
#                                       'Soup',
#               'brand_type': 1,
#               'food_name': 'Cream of Potato with Bacon Soup',
#               'locale': 'en_US',
#               'nf_calories': 310,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': '32f131278dc0e55e866faed2',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Eggs Benedict with Ham',
#               'brand_type': 1,
#               'food_name': 'Eggs Benedict with Ham',
#               'locale': 'en_US',
#               'nf_calories': 540,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c64062180c757050d94c54f7',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Eggsmart Western Sandwich',
#               'brand_type': 1,
#               'food_name': 'Eggsmart Western Sandwich',
#               'locale': 'en_US',
#               'nf_calories': 560,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218906bc65a90aea29e',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Fruit Bowl',
#               'brand_type': 1,
#               'food_name': 'Fruit Bowl',
#               'locale': 'en_US',
#               'nf_calories': 90,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': '32f13127624a9bcd6fb78d79',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Half Club Sandwich with Soup',
#               'brand_type': 1,
#               'food_name': 'Half Club Sandwich with Soup',
#               'locale': 'en_US',
#               'nf_calories': 390,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': '32f13127f6ebba833f4b98a0',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Herbal Tea',
#               'brand_type': 1,
#               'food_name': 'Herbal Tea',
#               'locale': 'en_US',
#               'nf_calories': 5,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': '32f131276ef507d15fa04d4d',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Hot Chocolate',
#               'brand_type': 1,
#               'food_name': 'Hot Chocolate',
#               'locale': 'en_US',
#               'nf_calories': 170,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218e898a2dbb033860a',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Meat Lovers Omelette',
#               'brand_type': 1,
#               'food_name': 'Meat Lovers Omelette',
#               'locale': 'en_US',
#               'nf_calories': 580,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218cc3d6a1302157198',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Mushroom Melter Burger',
#               'brand_type': 1,
#               'food_name': 'Mushroom Melter Burger',
#               'locale': 'en_US',
#               'nf_calories': 740,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c64062188ac263a2f8c5ac4f',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Poached Eggs & Turkey',
#               'brand_type': 1,
#               'food_name': 'Poached Eggs & Turkey',
#               'locale': 'en_US',
#               'nf_calories': 450,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': '32f1312757b6cc1df8af3333',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Sausage Links',
#               'brand_type': 1,
#               'food_name': 'Sausage Links',
#               'locale': 'en_US',
#               'nf_calories': 460,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218cc923d6332f22570',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Simpleton Burger with Canadian '
#                                       'Cheddar Cheese & Bacon',
#               'brand_type': 1,
#               'food_name': 'Simpleton Burger with Canadian Cheddar Cheese & '
#                            'Bacon',
#               'locale': 'en_US',
#               'nf_calories': 1090,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218a7a58e4a734bbb05',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Smoked Salmon Provolone '
#                                       'Omelette',
#               'brand_type': 1,
#               'food_name': 'Smoked Salmon Provolone Omelette',
#               'locale': 'en_US',
#               'nf_calories': 580,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218a5b2fa42363e8f08',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Spinach & Feta Cheese Omelette',
#               'brand_type': 1,
#               'food_name': 'Spinach & Feta Cheese Omelette',
#               'locale': 'en_US',
#               'nf_calories': 400,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c64062180c9dd844fb58ee47',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'},
#              {'brand_name': 'Eggsmart',
#               'brand_name_item_name': 'Eggsmart Sweet Potato Fries',
#               'brand_type': 1,
#               'food_name': 'Sweet Potato Fries',
#               'locale': 'en_US',
#               'nf_calories': 260,
#               'nix_brand_id': '59c2c80c0542cf2f660413b7',
#               'nix_item_id': 'c6406218683c5aa152b48409',
#               'photo': {'highres': None,
#                         'is_user_uploaded': False,
#                         'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#               'region': 1,
#               'serving_qty': 1,
#               'serving_unit': 'Serving'}],
#  'common': [{'common_type': None,
#              'food_name': 'eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/775_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '775'},
#             {'common_type': 2,
#              'food_name': 'eggo',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/2199_thumb.jpg'},
#              'serving_qty': 2,
#              'serving_unit': 'waffles',
#              'tag_id': '2199'},
#             {'common_type': None,
#              'food_name': 'eggnog',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1377_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'cup',
#              'tag_id': '1377'},
#             {'common_type': None,
#              'food_name': 'eggroll',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/27_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'piece',
#              'tag_id': '27'},
#             {'common_type': None,
#              'food_name': 'eggbake',
#              'locale': 'en_US',
#              'photo': {'highres': None,
#                        'is_user_uploaded': False,
#                        'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '8632'},
#             {'common_type': None,
#              'food_name': 'eggplant',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/540_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'medium eggplant',
#              'tag_id': '540'},
#             {'common_type': None,
#              'food_name': 'eggwhite',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/538_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '538'},
#             {'common_type': None,
#              'food_name': 'fried egg',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1741_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '1741'},
#             {'common_type': None,
#              'food_name': 'large egg',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/775_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '775'},
#             {'common_type': None,
#              'food_name': 'fried eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1741_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '1741'},
#             {'common_type': None,
#              'food_name': 'boiled egg',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/611_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '611'},
#             {'common_type': None,
#              'food_name': 'quail eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/4973_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'egg',
#              'tag_id': '4973'},
#             {'common_type': None,
#              'food_name': 'boiled eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/611_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '611'},
#             {'common_type': None,
#              'food_name': 'deviled egg',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/2172_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'half egg',
#              'tag_id': '2172'},
#             {'common_type': None,
#              'food_name': 'poached eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1836_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '1836'},
#             {'common_type': None,
#              'food_name': 'egg scrambled',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1738_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '1738'},
#             {'common_type': None,
#              'food_name': 'scramble eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1738_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '1738'},
#             {'common_type': None,
#              'food_name': 'scrambled eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1738_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '1738'},
#             {'common_type': None,
#              'food_name': 'hard boiled egg',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/611_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '611'},
#             {'common_type': None,
#              'food_name': 'hard boiled eggs',
#              'locale': 'en_US',
#              'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/611_thumb.jpg'},
#              'serving_qty': 1,
#              'serving_unit': 'large',
#              'tag_id': '611'}]}

# %%
# logging.debug(r4.text)

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/natural/tags/"    #   Returns the nutrients for all foods in the posted query
url = base_url + endpoint

headers = {
    'accept': 'application/json',
    'x-app-id': app_id,
    'x-app-key': api_key,
    'x-remote-user-id': '0',
#     'Content-Type': 'application/json',
}


data = {
    'query': "egg",
#     'num_servings': 1,
#     'aggregate': 'mashed potatoes',
#     'use_raw_foods': False,
#     'include_subrecipe: False,
#     'timezone': "US/Eastern",
#     'consumed_at': ISO8601,
#     'lat': '',
#     'lng': '',
#     'meal_type': ,
#     'use_branded_foods': False
#     'locale': '',
}

r5 = requests.post(url, headers=headers, json=data)

# %%
logging.debug((r5.text))

# %%
j5 = r5.json()
j5
# Out:
# [{'SERVING_WEIGHT_GRAMS': 50,
#   'MEASURE': 'large',
#   'TAG_ID': 775,
#   'TAG_IMAGE': 'https://d2xdmhkmkbyw75.cloudfront.net/775_thumb.jpg',
#   'TAG_IMAGE_HIGHRES': 'https://d2xdmhkmkbyw75.cloudfront.net/775_highres.jpg',
#   'ITEM': 'egg',
#   'TAG_NAME': 'raw eggs',
#   'NDB_NO': 1123,
#   'ALT_MEASURES': [{'serving_weight': 38,
#     'measure': 'small',
#     'seq': 7,
#     'qty': 1},
#    {'serving_weight': 44, 'measure': 'medium', 'seq': 6, 'qty': 1},
#    {'serving_weight': 50, 'measure': 'large', 'seq': 1, 'qty': 1},
#    {'serving_weight': 63, 'measure': 'jumbo', 'seq': 3, 'qty': 1},
#    {'serving_weight': 56, 'measure': 'extra large', 'seq': 2, 'qty': 1},
#    {'serving_weight': 243,
#     'measure': 'cup (4.86 large eggs)',
#     'seq': 5,
#     'qty': 1},
#    {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100}],
#   'QUANTITY': '1.0'}]

# %%
path = 'C:\\Users\\soria\\Documents\\resources\\data\\nutritionix_data\\'
file = "Nutritionix API v2 - Full Nutrient USDA Field Mapping [PUBLIC] - Attributes for natural endpoint.csv"

nutrient_df_full = pd.read_csv(path+file)
nutrient_df_full.head()
# Out:
#    attr_id  2018 NFP    usda_tag                          name  unit notes
# 0      301         1          CA                   Calcium, Ca    mg   NaN
# 1      205         1      CHOCDF   Carbohydrate, by difference     g   NaN
# 2      601         1       CHOLE                   Cholesterol    mg   NaN
# 3      208         1  ENERC_KCAL                        Energy  kcal   NaN
# 4      606         1       FASAT  Fatty acids, total saturated     g   NaN

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/nutrition_topics"    #   fetch a list of all nutrition topics; no params
url = base_url + endpoint

r2 = requests.get(url, headers=headers)

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
mongoDb = client.serious_eats_test2

# %%
collection = mongoDb['Chinese Recipes']
recipe_dict = collection.find_one({}, {'_id':False})
recipe_dict
# Out:
# {'topic': 'Chinese Recipes',
#  'source': 'serious_eats',
#  'recipe_title': "\nSweet and Sour Sauce\nToss it on fried chicken to make the best sweet and sour chicken you'll ever eat.\n",
#  'recipe_url': 'https://www.seriouseats.com/recipes/2012/01/sweet-and-sour-sauce.html',
#  'category_trees': [['Recipes', 'Cuisine', 'Asian', 'Chinese'],
#   ['Recipes', 'Meal', 'Vegetarian'],
#   ['Recipes', 'Meal', 'Quick and Easy'],
#   ['Recipes', 'Meal', 'Condiments and Sauces'],
#   ['Recipes', 'Method', 'Stovetop']],
#  'recipe': {'name': 'Sweet and Sour Sauce Recipe',
#   'rating_count': '2',
#   'rating_value': '3',
#   'author': 'Joshua Bousel',
#   'job_title': 'Contributor',
#   'description': 'Homemade sweet and sour sauce is quick, easy, and the perfect condiment for Chinese takeout or your own fried chicken.',
#   'keywords': 'chinese, condiment, easy, quick, sauce, sauced, takeout',
#   'categories': ['Vegetarian',
#    'Quick and Easy',
#    'Condiments and Sauces',
#    'Stovetop'],
#   'cuisine': 'Chinese',
#   'ingredients': ['1 tablespoon cornstarch (about 1/4 ounce; 7g)',
#    '1 tablespoon (15ml) water ',
#    '2/3 cup (160ml) pineapple juice ',
#    '1/3 cup (80ml) rice vinegar ',
#    '1/3 cup (74g) light brown sugar ',
#    '3 tablespoons (45ml) ketchup ',
#    '1 tablespoon (15ml) soy sauce'],
#   'steps': {'step_1': 'In a small bowl, whisk together cornstarch and water. Set aside.',
#    'step_2': 'In a medium saucepan, combine pineapple juice, rice vinegar, brown sugar, ketchup, and soy sauce and bring to a boil over medium heat. Stir in cornstarch slurry and cook until thickened, about 1 to 2 minutes. Remove from heat and use immediately or store in an airtight container in the refrigerator for up to 2 weeks.'},
#   'recipe_yield': 'Makes 1 cup (240ml)',
#   'time': '10.0'},
#  'uploaded': datetime.datetime(2019, 2, 24, 15, 28, 5, 236000)}

# %%
ing_string = recipe_dict['recipe']['ingredients']
ing_string = ' '.join(ing_string)
ing_string
# Out:
# '1 tablespoon cornstarch (about 1/4 ounce; 7g) 1 tablespoon (15ml) water  2/3 cup (160ml) pineapple juice  1/3 cup (80ml) rice vinegar  1/3 cup (74g) light brown sugar  3 tablespoons (45ml) ketchup  1 tablespoon (15ml) soy sauce'

# %%
base_url = "https://trackapi.nutritionix.com" 
endpoint = "/v2/natural/nutrients/"    #   Returns the nutrients for all foods in the posted query
url = base_url + endpoint

headers = {
    'accept': 'application/json',
    'x-app-id': app_id,
    'x-app-key': api_key,
    'x-remote-user-id': '0',
#     'Content-Type': 'application/json',
}

data = { 
    "query": ing_string,
    "aggregate": recipe_dict['recipe']['name'],
    "num_servings": 0, 
    "line_delimited": False, 
    "use_raw_foods": False, 
    "include_subrecipe": True, 
    "lat": 0, 
    "lng": 0, 
    "meal_type": 0, 
    "use_branded_foods": False, 
    "locale": "en_US"
}

# json param replaces dumps and auto sets content-type

# data = json.dumps(data)
# r3 = requests.post(url, headers=headers, data=data)


recp_resp = requests.post(url, headers=headers, json=data)

# %%
recp_resp.json()
# Out:
# {'foods': [{'food_name': 'cornstarch',
#    'brand_name': None,
#    'serving_qty': 1,
#    'serving_unit': 'tablespoon',
#    'serving_weight_grams': 8,
#    'nf_calories': 30.48,
#    'nf_total_fat': 0,
#    'nf_saturated_fat': 0,
#    'nf_cholesterol': 0,
#    'nf_sodium': 0.72,
#    'nf_total_carbohydrate': 7.3,
#    'nf_dietary_fiber': 0.07,
#    'nf_sugars': 0,
#    'nf_protein': 0.02,
#    'nf_potassium': 0.24,
#    'nf_p': 1.04,
#    'full_nutrients': [{'attr_id': 203, 'value': 0.0208},
#     {'attr_id': 204, 'value': 0.004},
#     {'attr_id': 205, 'value': 7.3016},
#     {'attr_id': 207, 'value': 0.0072},
#     {'attr_id': 208, 'value': 30.48},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 0.6656},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 127.52},
#     {'attr_id': 269, 'value': 0},
#     {'attr_id': 291, 'value': 0.072},
#     {'attr_id': 301, 'value': 0.16},
#     {'attr_id': 303, 'value': 0.0376},
#     {'attr_id': 304, 'value': 0.24},
#     {'attr_id': 305, 'value': 1.04},
#     {'attr_id': 306, 'value': 0.24},
#     {'attr_id': 307, 'value': 0.72},
#     {'attr_id': 309, 'value': 0.0048},
#     {'attr_id': 312, 'value': 0.004},
#     {'attr_id': 315, 'value': 0.0042},
#     {'attr_id': 317, 'value': 0.224},
#     {'attr_id': 318, 'value': 0},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 0},
#     {'attr_id': 321, 'value': 0},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 0},
#     {'attr_id': 338, 'value': 0},
#     {'attr_id': 341, 'value': 0},
#     {'attr_id': 342, 'value': 0},
#     {'attr_id': 343, 'value': 0},
#     {'attr_id': 344, 'value': 0},
#     {'attr_id': 345, 'value': 0},
#     {'attr_id': 346, 'value': 0},
#     {'attr_id': 347, 'value': 0},
#     {'attr_id': 401, 'value': 0},
#     {'attr_id': 404, 'value': 0},
#     {'attr_id': 405, 'value': 0},
#     {'attr_id': 406, 'value': 0},
#     {'attr_id': 410, 'value': 0},
#     {'attr_id': 415, 'value': 0},
#     {'attr_id': 417, 'value': 0},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 0.032},
#     {'attr_id': 430, 'value': 0},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 0},
#     {'attr_id': 435, 'value': 0},
#     {'attr_id': 501, 'value': 0.0001},
#     {'attr_id': 502, 'value': 0.0007},
#     {'attr_id': 503, 'value': 0.0008},
#     {'attr_id': 504, 'value': 0.0029},
#     {'attr_id': 505, 'value': 0.0005},
#     {'attr_id': 506, 'value': 0.0005},
#     {'attr_id': 507, 'value': 0.0005},
#     {'attr_id': 508, 'value': 0.001},
#     {'attr_id': 509, 'value': 0.0008},
#     {'attr_id': 510, 'value': 0.0011},
#     {'attr_id': 511, 'value': 0.001},
#     {'attr_id': 512, 'value': 0.0006},
#     {'attr_id': 513, 'value': 0.0015},
#     {'attr_id': 514, 'value': 0.0016},
#     {'attr_id': 515, 'value': 0.0042},
#     {'attr_id': 516, 'value': 0.0007},
#     {'attr_id': 517, 'value': 0.0019},
#     {'attr_id': 518, 'value': 0.001},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 606, 'value': 0.0007},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0.0007},
#     {'attr_id': 614, 'value': 0.0001},
#     {'attr_id': 617, 'value': 0.0013},
#     {'attr_id': 618, 'value': 0.002},
#     {'attr_id': 619, 'value': 0},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0.0013},
#     {'attr_id': 646, 'value': 0.002}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 20027,
#    'tags': {'item': 'cornstarch',
#     'measure': 'tablespoon',
#     'quantity': '1',
#     'food_group': 9,
#     'tag_id': 509},
#    'alt_measures': [{'serving_weight': 128,
#      'measure': 'cup',
#      'seq': 1,
#      'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100},
#     {'serving_weight': 2.67, 'measure': 'tsp', 'seq': 101, 'qty': 1},
#     {'serving_weight': 8, 'measure': 'tbsp', 'seq': 102, 'qty': 1}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/509_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/509_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None},
#   {'food_name': 'water',
#    'brand_name': None,
#    'serving_qty': 1,
#    'serving_unit': 'serving 8 fl oz',
#    'serving_weight_grams': 237,
#    'nf_calories': 0,
#    'nf_total_fat': 0,
#    'nf_saturated_fat': 0,
#    'nf_cholesterol': 0,
#    'nf_sodium': 9.48,
#    'nf_total_carbohydrate': 0,
#    'nf_dietary_fiber': 0,
#    'nf_sugars': 0,
#    'nf_protein': 0,
#    'nf_potassium': 0,
#    'nf_p': 0,
#    'full_nutrients': [{'attr_id': 203, 'value': 0},
#     {'attr_id': 204, 'value': 0},
#     {'attr_id': 205, 'value': 0},
#     {'attr_id': 207, 'value': 0.237},
#     {'attr_id': 208, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 236.763},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 0},
#     {'attr_id': 269, 'value': 0},
#     {'attr_id': 291, 'value': 0},
#     {'attr_id': 301, 'value': 7.11},
#     {'attr_id': 303, 'value': 0},
#     {'attr_id': 304, 'value': 2.37},
#     {'attr_id': 305, 'value': 0},
#     {'attr_id': 306, 'value': 0},
#     {'attr_id': 307, 'value': 9.48},
#     {'attr_id': 309, 'value': 0.0237},
#     {'attr_id': 312, 'value': 0.0237},
#     {'attr_id': 313, 'value': 168.744},
#     {'attr_id': 315, 'value': 0},
#     {'attr_id': 317, 'value': 0},
#     {'attr_id': 318, 'value': 0},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 0},
#     {'attr_id': 321, 'value': 0},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 0},
#     {'attr_id': 338, 'value': 0},
#     {'attr_id': 401, 'value': 0},
#     {'attr_id': 404, 'value': 0},
#     {'attr_id': 405, 'value': 0},
#     {'attr_id': 406, 'value': 0},
#     {'attr_id': 410, 'value': 0},
#     {'attr_id': 415, 'value': 0},
#     {'attr_id': 417, 'value': 0},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 0},
#     {'attr_id': 430, 'value': 0},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 0},
#     {'attr_id': 435, 'value': 0},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 605, 'value': 0},
#     {'attr_id': 606, 'value': 0},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0},
#     {'attr_id': 614, 'value': 0},
#     {'attr_id': 617, 'value': 0},
#     {'attr_id': 618, 'value': 0},
#     {'attr_id': 619, 'value': 0},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0},
#     {'attr_id': 646, 'value': 0}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 14411,
#    'tags': {'item': 'tap water',
#     'measure': None,
#     'quantity': '1',
#     'food_group': 9,
#     'tag_id': 4483},
#    'alt_measures': [{'serving_weight': 1000,
#      'measure': 'liter',
#      'seq': 3,
#      'qty': 1},
#     {'serving_weight': 237, 'measure': 'serving 8 fl oz', 'seq': 2, 'qty': 1},
#     {'serving_weight': 29.6, 'measure': 'fl oz', 'seq': 1, 'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100},
#     {'serving_weight': 236.8, 'measure': 'cup', 'seq': 100, 'qty': 1},
#     {'serving_weight': 4.93, 'measure': 'tsp', 'seq': 101, 'qty': 1},
#     {'serving_weight': 14.8, 'measure': 'tbsp', 'seq': 102, 'qty': 1}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/4483_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/4483_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None},
#   {'food_name': 'pineapple juice',
#    'brand_name': None,
#    'serving_qty': 0.67,
#    'serving_unit': 'cup',
#    'serving_weight_grams': 167.5,
#    'nf_calories': 88.78,
#    'nf_total_fat': 0.2,
#    'nf_saturated_fat': 0.01,
#    'nf_cholesterol': 0,
#    'nf_sodium': 3.35,
#    'nf_total_carbohydrate': 21.56,
#    'nf_dietary_fiber': 0.34,
#    'nf_sugars': 16.72,
#    'nf_protein': 0.6,
#    'nf_potassium': 217.75,
#    'nf_p': 13.4,
#    'full_nutrients': [{'attr_id': 203, 'value': 0.603},
#     {'attr_id': 204, 'value': 0.201},
#     {'attr_id': 205, 'value': 21.5573},
#     {'attr_id': 207, 'value': 0.469},
#     {'attr_id': 208, 'value': 88.775},
#     {'attr_id': 210, 'value': 2.5628},
#     {'attr_id': 211, 'value': 7.7888},
#     {'attr_id': 212, 'value': 6.3818},
#     {'attr_id': 213, 'value': 0},
#     {'attr_id': 214, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 144.6698},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 368.5},
#     {'attr_id': 269, 'value': 16.7165},
#     {'attr_id': 287, 'value': 0},
#     {'attr_id': 291, 'value': 0.335},
#     {'attr_id': 301, 'value': 21.775},
#     {'attr_id': 303, 'value': 0.5193},
#     {'attr_id': 304, 'value': 20.1},
#     {'attr_id': 305, 'value': 13.4},
#     {'attr_id': 306, 'value': 217.75},
#     {'attr_id': 307, 'value': 3.35},
#     {'attr_id': 309, 'value': 0.1843},
#     {'attr_id': 312, 'value': 0.1156},
#     {'attr_id': 313, 'value': 9.2125},
#     {'attr_id': 315, 'value': 0.8442},
#     {'attr_id': 317, 'value': 0.1675},
#     {'attr_id': 318, 'value': 8.375},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 0},
#     {'attr_id': 321, 'value': 5.025},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0.0335},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 0},
#     {'attr_id': 338, 'value': 0},
#     {'attr_id': 401, 'value': 73.365},
#     {'attr_id': 404, 'value': 0.0972},
#     {'attr_id': 405, 'value': 0.0352},
#     {'attr_id': 406, 'value': 0.3333},
#     {'attr_id': 410, 'value': 0.0938},
#     {'attr_id': 415, 'value': 0.1675},
#     {'attr_id': 417, 'value': 30.15},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 5.5275},
#     {'attr_id': 430, 'value': 0.5025},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 30.15},
#     {'attr_id': 435, 'value': 30.15},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 605, 'value': 0},
#     {'attr_id': 606, 'value': 0.0134},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0.0084},
#     {'attr_id': 614, 'value': 0.005},
#     {'attr_id': 617, 'value': 0.0201},
#     {'attr_id': 618, 'value': 0.0402},
#     {'attr_id': 619, 'value': 0.0302},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0.0034},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0.0235},
#     {'attr_id': 646, 'value': 0.0704}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 9409,
#    'tags': {'item': 'pineapple juice',
#     'measure': 'cup',
#     'quantity': '0.67',
#     'food_group': 3,
#     'tag_id': 3425},
#    'alt_measures': [{'serving_weight': 31.3,
#      'measure': 'fl oz',
#      'seq': 2,
#      'qty': 1},
#     {'serving_weight': 250, 'measure': 'cup', 'seq': 1, 'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100},
#     {'serving_weight': 5.21, 'measure': 'tsp', 'seq': 101, 'qty': 1},
#     {'serving_weight': 15.63, 'measure': 'tbsp', 'seq': 102, 'qty': 1}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/3425_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/3425_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None},
#   {'food_name': 'rice vinegar',
#    'brand_name': None,
#    'serving_qty': 0.33,
#    'serving_unit': 'cup',
#    'serving_weight_grams': 78.54,
#    'nf_calories': 14.14,
#    'nf_total_fat': 0,
#    'nf_saturated_fat': 0,
#    'nf_cholesterol': 0,
#    'nf_sodium': 1.57,
#    'nf_total_carbohydrate': 0.03,
#    'nf_dietary_fiber': 0,
#    'nf_sugars': 0.03,
#    'nf_protein': 0,
#    'nf_potassium': 1.57,
#    'nf_p': 3.14,
#    'full_nutrients': [{'attr_id': 203, 'value': 0},
#     {'attr_id': 204, 'value': 0},
#     {'attr_id': 205, 'value': 0.0314},
#     {'attr_id': 207, 'value': 0.0157},
#     {'attr_id': 208, 'value': 14.1372},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 74.4402},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 59.6904},
#     {'attr_id': 269, 'value': 0.0314},
#     {'attr_id': 291, 'value': 0},
#     {'attr_id': 301, 'value': 4.7124},
#     {'attr_id': 303, 'value': 0.0236},
#     {'attr_id': 304, 'value': 0.7854},
#     {'attr_id': 305, 'value': 3.1416},
#     {'attr_id': 306, 'value': 1.5708},
#     {'attr_id': 307, 'value': 1.5708},
#     {'attr_id': 309, 'value': 0.0079},
#     {'attr_id': 312, 'value': 0.0047},
#     {'attr_id': 315, 'value': 0.0432},
#     {'attr_id': 317, 'value': 0.3927},
#     {'attr_id': 318, 'value': 0},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 0},
#     {'attr_id': 321, 'value': 0},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 0},
#     {'attr_id': 338, 'value': 0},
#     {'attr_id': 401, 'value': 0},
#     {'attr_id': 404, 'value': 0},
#     {'attr_id': 405, 'value': 0},
#     {'attr_id': 406, 'value': 0},
#     {'attr_id': 410, 'value': 0},
#     {'attr_id': 415, 'value': 0},
#     {'attr_id': 417, 'value': 0},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 0},
#     {'attr_id': 430, 'value': 0},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 0},
#     {'attr_id': 435, 'value': 0},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 605, 'value': 0},
#     {'attr_id': 606, 'value': 0},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0},
#     {'attr_id': 614, 'value': 0},
#     {'attr_id': 617, 'value': 0},
#     {'attr_id': 618, 'value': 0},
#     {'attr_id': 619, 'value': 0},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0},
#     {'attr_id': 646, 'value': 0}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 2053,
#    'tags': {'item': 'white vinegar',
#     'measure': 'cup',
#     'quantity': '0.33',
#     'food_group': 0,
#     'tag_id': 1187},
#    'alt_measures': [{'serving_weight': 5,
#      'measure': 'tsp',
#      'seq': 3,
#      'qty': 1},
#     {'serving_weight': 14.9, 'measure': 'tbsp', 'seq': 1, 'qty': 1},
#     {'serving_weight': 238, 'measure': 'cup', 'seq': 2, 'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1187_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/1187_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None},
#   {'food_name': 'light brown sugar',
#    'brand_name': None,
#    'serving_qty': 0.33,
#    'serving_unit': 'cup',
#    'serving_weight_grams': 60.23,
#    'nf_calories': 228.86,
#    'nf_total_fat': 0,
#    'nf_saturated_fat': 0,
#    'nf_cholesterol': 0,
#    'nf_sodium': 16.86,
#    'nf_total_carbohydrate': 59.07,
#    'nf_dietary_fiber': 0,
#    'nf_sugars': 58.43,
#    'nf_protein': 0.07,
#    'nf_potassium': 80.1,
#    'nf_p': 2.41,
#    'full_nutrients': [{'attr_id': 203, 'value': 0.0723},
#     {'attr_id': 204, 'value': 0},
#     {'attr_id': 205, 'value': 59.0747},
#     {'attr_id': 207, 'value': 0.271},
#     {'attr_id': 208, 'value': 228.855},
#     {'attr_id': 210, 'value': 56.9488},
#     {'attr_id': 211, 'value': 0.813},
#     {'attr_id': 212, 'value': 0.6685},
#     {'attr_id': 213, 'value': 0},
#     {'attr_id': 214, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 0.807},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 957.5775},
#     {'attr_id': 269, 'value': 58.4303},
#     {'attr_id': 287, 'value': 0},
#     {'attr_id': 291, 'value': 0},
#     {'attr_id': 301, 'value': 49.9868},
#     {'attr_id': 303, 'value': 0.4276},
#     {'attr_id': 304, 'value': 5.4203},
#     {'attr_id': 305, 'value': 2.409},
#     {'attr_id': 306, 'value': 80.0993},
#     {'attr_id': 307, 'value': 16.863},
#     {'attr_id': 309, 'value': 0.0181},
#     {'attr_id': 312, 'value': 0.0283},
#     {'attr_id': 315, 'value': 0.0385},
#     {'attr_id': 317, 'value': 0.7227},
#     {'attr_id': 318, 'value': 0},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 0},
#     {'attr_id': 321, 'value': 0},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 0},
#     {'attr_id': 338, 'value': 0},
#     {'attr_id': 401, 'value': 0},
#     {'attr_id': 404, 'value': 0},
#     {'attr_id': 405, 'value': 0},
#     {'attr_id': 406, 'value': 0.0663},
#     {'attr_id': 410, 'value': 0.0795},
#     {'attr_id': 415, 'value': 0.0247},
#     {'attr_id': 417, 'value': 0.6023},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 1.3852},
#     {'attr_id': 430, 'value': 0},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 0.6023},
#     {'attr_id': 435, 'value': 0.6023},
#     {'attr_id': 454, 'value': 0.0602},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 606, 'value': 0},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0},
#     {'attr_id': 614, 'value': 0},
#     {'attr_id': 617, 'value': 0},
#     {'attr_id': 618, 'value': 0},
#     {'attr_id': 619, 'value': 0},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0},
#     {'attr_id': 646, 'value': 0}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 19334,
#    'tags': {'item': 'brown sugar',
#     'measure': 'cup',
#     'quantity': '0.33',
#     'food_group': 9,
#     'tag_id': 439},
#    'alt_measures': [{'serving_weight': 3.2,
#      'measure': 'tsp brownulated',
#      'seq': 5,
#      'qty': 1},
#     {'serving_weight': 3, 'measure': 'tsp unpacked', 'seq': 1, 'qty': 1},
#     {'serving_weight': 4.6, 'measure': 'tsp packed', 'seq': 4, 'qty': 1},
#     {'serving_weight': 145, 'measure': 'cup unpacked', 'seq': 3, 'qty': 1},
#     {'serving_weight': 220, 'measure': 'cup packed', 'seq': 2, 'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/439_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/439_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None},
#   {'food_name': 'ketchup',
#    'brand_name': None,
#    'serving_qty': 3,
#    'serving_unit': 'tablespoons',
#    'serving_weight_grams': 48,
#    'nf_calories': 48.48,
#    'nf_total_fat': 0.05,
#    'nf_saturated_fat': 0.01,
#    'nf_cholesterol': 0,
#    'nf_sodium': 435.36,
#    'nf_total_carbohydrate': 13.15,
#    'nf_dietary_fiber': 0.14,
#    'nf_sugars': 10.21,
#    'nf_protein': 0.5,
#    'nf_potassium': 134.88,
#    'nf_p': 12.48,
#    'full_nutrients': [{'attr_id': 203, 'value': 0.4992},
#     {'attr_id': 204, 'value': 0.048},
#     {'attr_id': 205, 'value': 13.152},
#     {'attr_id': 207, 'value': 1.4112},
#     {'attr_id': 208, 'value': 48.48},
#     {'attr_id': 210, 'value': 1.104},
#     {'attr_id': 211, 'value': 4.92},
#     {'attr_id': 212, 'value': 4.1856},
#     {'attr_id': 213, 'value': 0},
#     {'attr_id': 214, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 32.8848},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 203.04},
#     {'attr_id': 269, 'value': 10.2096},
#     {'attr_id': 287, 'value': 0},
#     {'attr_id': 291, 'value': 0.144},
#     {'attr_id': 301, 'value': 7.2},
#     {'attr_id': 303, 'value': 0.168},
#     {'attr_id': 304, 'value': 6.24},
#     {'attr_id': 305, 'value': 12.48},
#     {'attr_id': 306, 'value': 134.88},
#     {'attr_id': 307, 'value': 435.36},
#     {'attr_id': 309, 'value': 0.0816},
#     {'attr_id': 312, 'value': 0.0408},
#     {'attr_id': 313, 'value': 7.248},
#     {'attr_id': 315, 'value': 0.0403},
#     {'attr_id': 317, 'value': 0.336},
#     {'attr_id': 318, 'value': 252.96},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 12.48},
#     {'attr_id': 321, 'value': 151.68},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0.7008},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 5789.76},
#     {'attr_id': 338, 'value': 77.28},
#     {'attr_id': 341, 'value': 0},
#     {'attr_id': 342, 'value': 0.0624},
#     {'attr_id': 343, 'value': 0},
#     {'attr_id': 401, 'value': 1.968},
#     {'attr_id': 404, 'value': 0.0053},
#     {'attr_id': 405, 'value': 0.0797},
#     {'attr_id': 406, 'value': 0.6883},
#     {'attr_id': 410, 'value': 0.0226},
#     {'attr_id': 415, 'value': 0.0758},
#     {'attr_id': 417, 'value': 4.32},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 6},
#     {'attr_id': 429, 'value': 0},
#     {'attr_id': 430, 'value': 1.44},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 4.32},
#     {'attr_id': 435, 'value': 4.32},
#     {'attr_id': 454, 'value': 0.096},
#     {'attr_id': 501, 'value': 0.0024},
#     {'attr_id': 502, 'value': 0.0091},
#     {'attr_id': 503, 'value': 0.0067},
#     {'attr_id': 504, 'value': 0.0101},
#     {'attr_id': 505, 'value': 0.011},
#     {'attr_id': 506, 'value': 0.0024},
#     {'attr_id': 507, 'value': 0.0024},
#     {'attr_id': 508, 'value': 0.0101},
#     {'attr_id': 509, 'value': 0.0043},
#     {'attr_id': 510, 'value': 0.0067},
#     {'attr_id': 511, 'value': 0.0077},
#     {'attr_id': 512, 'value': 0.0062},
#     {'attr_id': 513, 'value': 0.0158},
#     {'attr_id': 514, 'value': 0.0638},
#     {'attr_id': 515, 'value': 0.1675},
#     {'attr_id': 516, 'value': 0.0077},
#     {'attr_id': 517, 'value': 0.0058},
#     {'attr_id': 518, 'value': 0.0101},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 605, 'value': 0},
#     {'attr_id': 606, 'value': 0.0067},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0.0048},
#     {'attr_id': 614, 'value': 0.0019},
#     {'attr_id': 617, 'value': 0.0072},
#     {'attr_id': 618, 'value': 0.0187},
#     {'attr_id': 619, 'value': 0.0005},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0.0005},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0.0072},
#     {'attr_id': 646, 'value': 0.0197}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 11935,
#    'tags': {'item': 'ketchup',
#     'measure': 'tablespoons',
#     'quantity': '3',
#     'food_group': 9,
#     'tag_id': 1013},
#    'alt_measures': [{'serving_weight': 9,
#      'measure': 'packet',
#      'seq': 2,
#      'qty': 1},
#     {'serving_weight': 17, 'measure': 'tbsp', 'seq': 1, 'qty': 1},
#     {'serving_weight': 240, 'measure': 'cup', 'seq': 3, 'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100},
#     {'serving_weight': 5, 'measure': 'tsp', 'seq': 101, 'qty': 1}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/1013_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/1013_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None},
#   {'food_name': 'soy sauce',
#    'brand_name': None,
#    'serving_qty': 1,
#    'serving_unit': 'tablespoon',
#    'serving_weight_grams': 15.95,
#    'nf_calories': 8.45,
#    'nf_total_fat': 0.09,
#    'nf_saturated_fat': 0.01,
#    'nf_cholesterol': 0,
#    'nf_sodium': 875.9,
#    'nf_total_carbohydrate': 0.79,
#    'nf_dietary_fiber': 0.13,
#    'nf_sugars': 0.06,
#    'nf_protein': 1.3,
#    'nf_potassium': 69.36,
#    'nf_p': 26.47,
#    'full_nutrients': [{'attr_id': 203, 'value': 1.298},
#     {'attr_id': 204, 'value': 0.0909},
#     {'attr_id': 205, 'value': 0.7861},
#     {'attr_id': 207, 'value': 2.4254},
#     {'attr_id': 208, 'value': 8.4513},
#     {'attr_id': 210, 'value': 0.016},
#     {'attr_id': 211, 'value': 0.0478},
#     {'attr_id': 212, 'value': 0},
#     {'attr_id': 213, 'value': 0},
#     {'attr_id': 214, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 11.3455},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 35.3998},
#     {'attr_id': 269, 'value': 0.0638},
#     {'attr_id': 287, 'value': 0},
#     {'attr_id': 291, 'value': 0.1276},
#     {'attr_id': 301, 'value': 5.2621},
#     {'attr_id': 303, 'value': 0.2312},
#     {'attr_id': 304, 'value': 11.7999},
#     {'attr_id': 305, 'value': 26.4701},
#     {'attr_id': 306, 'value': 69.3644},
#     {'attr_id': 307, 'value': 875.9046},
#     {'attr_id': 309, 'value': 0.1387},
#     {'attr_id': 312, 'value': 0.0069},
#     {'attr_id': 315, 'value': 0.1623},
#     {'attr_id': 317, 'value': 0.0797},
#     {'attr_id': 318, 'value': 0},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 0},
#     {'attr_id': 321, 'value': 0},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 0},
#     {'attr_id': 338, 'value': 0},
#     {'attr_id': 401, 'value': 0},
#     {'attr_id': 404, 'value': 0.0053},
#     {'attr_id': 405, 'value': 0.0263},
#     {'attr_id': 406, 'value': 0.3502},
#     {'attr_id': 410, 'value': 0.0474},
#     {'attr_id': 415, 'value': 0.0236},
#     {'attr_id': 417, 'value': 2.2324},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 2.9181},
#     {'attr_id': 430, 'value': 0},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 2.2324},
#     {'attr_id': 435, 'value': 2.2324},
#     {'attr_id': 454, 'value': 4.7519},
#     {'attr_id': 501, 'value': 0.0153},
#     {'attr_id': 502, 'value': 0.0432},
#     {'attr_id': 503, 'value': 0.0507},
#     {'attr_id': 504, 'value': 0.0856},
#     {'attr_id': 505, 'value': 0.0608},
#     {'attr_id': 506, 'value': 0.0155},
#     {'attr_id': 507, 'value': 0.0188},
#     {'attr_id': 508, 'value': 0.0563},
#     {'attr_id': 509, 'value': 0.0389},
#     {'attr_id': 510, 'value': 0.0529},
#     {'attr_id': 511, 'value': 0.0738},
#     {'attr_id': 512, 'value': 0.0278},
#     {'attr_id': 513, 'value': 0.0469},
#     {'attr_id': 514, 'value': 0.1147},
#     {'attr_id': 515, 'value': 0.2518},
#     {'attr_id': 516, 'value': 0.0474},
#     {'attr_id': 517, 'value': 0.0786},
#     {'attr_id': 518, 'value': 0.0619},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 605, 'value': 0},
#     {'attr_id': 606, 'value': 0.0116},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0.0093},
#     {'attr_id': 614, 'value': 0.0011},
#     {'attr_id': 617, 'value': 0.0128},
#     {'attr_id': 618, 'value': 0.0373},
#     {'attr_id': 619, 'value': 0.0046},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0.014},
#     {'attr_id': 646, 'value': 0.0419}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T22:53:55+00:00',
#    'metadata': {'is_raw_food': False},
#    'source': 1,
#    'ndb_no': 16123,
#    'tags': {'item': 'dark soy sauce',
#     'measure': 'tablespoon',
#     'quantity': None,
#     'food_group': 0,
#     'tag_id': 9306},
#    'alt_measures': [{'serving_weight': 8.9,
#      'measure': 'individual packet',
#      'seq': 4,
#      'qty': 1},
#     {'serving_weight': 5.3, 'measure': 'tsp', 'seq': 2, 'qty': 1},
#     {'serving_weight': 16, 'measure': 'tbsp', 'seq': 1, 'qty': 1},
#     {'serving_weight': 255, 'measure': 'cup', 'seq': 3, 'qty': 1},
#     {'serving_weight': 100, 'measure': 'g', 'seq': None, 'qty': 100}],
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2xdmhkmkbyw75.cloudfront.net/9306_thumb.jpg',
#     'highres': 'https://d2xdmhkmkbyw75.cloudfront.net/9306_highres.jpg',
#     'is_user_uploaded': False},
#    'sub_recipe': None}]}

# %%
recp_resp.json()
# Out:
# {'foods': [{'food_name': 'Sweet and Sour Sauce Recipe',
#    'brand_name': None,
#    'serving_qty': 1,
#    'serving_unit': 'serving',
#    'serving_weight_grams': 615.22,
#    'nf_calories': 419.18,
#    'nf_total_fat': 0.34,
#    'nf_saturated_fat': 0.03,
#    'nf_cholesterol': 0,
#    'nf_sodium': 1343.25,
#    'nf_total_carbohydrate': 101.9,
#    'nf_dietary_fiber': 0.68,
#    'nf_sugars': 85.45,
#    'nf_protein': 2.49,
#    'nf_potassium': 503.9,
#    'nf_p': 58.94,
#    'full_nutrients': [{'attr_id': 203, 'value': 2.4933},
#     {'attr_id': 204, 'value': 0.3439},
#     {'attr_id': 205, 'value': 101.9031},
#     {'attr_id': 207, 'value': 4.8365},
#     {'attr_id': 208, 'value': 419.1785},
#     {'attr_id': 210, 'value': 60.6315},
#     {'attr_id': 211, 'value': 13.5696},
#     {'attr_id': 212, 'value': 11.2359},
#     {'attr_id': 213, 'value': 0},
#     {'attr_id': 214, 'value': 0},
#     {'attr_id': 221, 'value': 0},
#     {'attr_id': 255, 'value': 501.5758},
#     {'attr_id': 262, 'value': 0},
#     {'attr_id': 263, 'value': 0},
#     {'attr_id': 268, 'value': 1751.7277},
#     {'attr_id': 269, 'value': 85.4516},
#     {'attr_id': 287, 'value': 0},
#     {'attr_id': 291, 'value': 0.6786},
#     {'attr_id': 301, 'value': 96.2063},
#     {'attr_id': 303, 'value': 1.4072},
#     {'attr_id': 304, 'value': 46.9556},
#     {'attr_id': 305, 'value': 58.9407},
#     {'attr_id': 306, 'value': 503.9044},
#     {'attr_id': 307, 'value': 1343.2484},
#     {'attr_id': 309, 'value': 0.459},
#     {'attr_id': 312, 'value': 0.224},
#     {'attr_id': 313, 'value': 185.2045},
#     {'attr_id': 315, 'value': 1.1328},
#     {'attr_id': 317, 'value': 1.9226},
#     {'attr_id': 318, 'value': 261.335},
#     {'attr_id': 319, 'value': 0},
#     {'attr_id': 320, 'value': 12.48},
#     {'attr_id': 321, 'value': 156.705},
#     {'attr_id': 322, 'value': 0},
#     {'attr_id': 323, 'value': 0.7343},
#     {'attr_id': 324, 'value': 0},
#     {'attr_id': 328, 'value': 0},
#     {'attr_id': 334, 'value': 0},
#     {'attr_id': 337, 'value': 5789.76},
#     {'attr_id': 338, 'value': 77.28},
#     {'attr_id': 341, 'value': 0},
#     {'attr_id': 342, 'value': 0.0624},
#     {'attr_id': 343, 'value': 0},
#     {'attr_id': 344, 'value': 0},
#     {'attr_id': 345, 'value': 0},
#     {'attr_id': 346, 'value': 0},
#     {'attr_id': 347, 'value': 0},
#     {'attr_id': 401, 'value': 75.333},
#     {'attr_id': 404, 'value': 0.1077},
#     {'attr_id': 405, 'value': 0.1412},
#     {'attr_id': 406, 'value': 1.4381},
#     {'attr_id': 410, 'value': 0.2432},
#     {'attr_id': 415, 'value': 0.2916},
#     {'attr_id': 417, 'value': 37.3047},
#     {'attr_id': 418, 'value': 0},
#     {'attr_id': 421, 'value': 15.8628},
#     {'attr_id': 429, 'value': 0},
#     {'attr_id': 430, 'value': 1.9425},
#     {'attr_id': 431, 'value': 0},
#     {'attr_id': 432, 'value': 37.3047},
#     {'attr_id': 435, 'value': 37.3047},
#     {'attr_id': 454, 'value': 4.9081},
#     {'attr_id': 501, 'value': 0.0178},
#     {'attr_id': 502, 'value': 0.0531},
#     {'attr_id': 503, 'value': 0.0582},
#     {'attr_id': 504, 'value': 0.0986},
#     {'attr_id': 505, 'value': 0.0723},
#     {'attr_id': 506, 'value': 0.0184},
#     {'attr_id': 507, 'value': 0.0217},
#     {'attr_id': 508, 'value': 0.0674},
#     {'attr_id': 509, 'value': 0.044},
#     {'attr_id': 510, 'value': 0.0608},
#     {'attr_id': 511, 'value': 0.0825},
#     {'attr_id': 512, 'value': 0.0346},
#     {'attr_id': 513, 'value': 0.0642},
#     {'attr_id': 514, 'value': 0.1801},
#     {'attr_id': 515, 'value': 0.4235},
#     {'attr_id': 516, 'value': 0.0558},
#     {'attr_id': 517, 'value': 0.0863},
#     {'attr_id': 518, 'value': 0.0729},
#     {'attr_id': 601, 'value': 0},
#     {'attr_id': 605, 'value': 0},
#     {'attr_id': 606, 'value': 0.0325},
#     {'attr_id': 607, 'value': 0},
#     {'attr_id': 608, 'value': 0},
#     {'attr_id': 609, 'value': 0},
#     {'attr_id': 610, 'value': 0},
#     {'attr_id': 611, 'value': 0},
#     {'attr_id': 612, 'value': 0},
#     {'attr_id': 613, 'value': 0.0231},
#     {'attr_id': 614, 'value': 0.0081},
#     {'attr_id': 617, 'value': 0.0413},
#     {'attr_id': 618, 'value': 0.0982},
#     {'attr_id': 619, 'value': 0.0353},
#     {'attr_id': 620, 'value': 0},
#     {'attr_id': 621, 'value': 0},
#     {'attr_id': 626, 'value': 0.0038},
#     {'attr_id': 627, 'value': 0},
#     {'attr_id': 628, 'value': 0},
#     {'attr_id': 629, 'value': 0},
#     {'attr_id': 630, 'value': 0},
#     {'attr_id': 631, 'value': 0},
#     {'attr_id': 645, 'value': 0.046},
#     {'attr_id': 646, 'value': 0.134}],
#    'nix_brand_name': None,
#    'nix_brand_id': None,
#    'nix_item_name': None,
#    'nix_item_id': None,
#    'upc': None,
#    'consumed_at': '2019-02-24T23:01:22+00:00',
#    'metadata': {},
#    'source': None,
#    'ndb_no': None,
#    'tags': None,
#    'alt_measures': None,
#    'lat': 0,
#    'lng': 0,
#    'meal_type': 0,
#    'photo': {'thumb': 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png',
#     'highres': None,
#     'is_user_uploaded': False},
#    'sub_recipe': None}]}

# %%
# pprint(unupdated)

# %%
r['topic']
# Out:
# {'African Recipes': [{'topic': 'African Recipes',
#    'recipe_url': 'https://www.seriouseats.com/recipes/2016/09/shakshuka-north-african-shirred-eggs-tomato-pepper-recipe.html',
#    'recipe_title': '\nShakshuka (North African–Style Poached Eggs in Spicy Tomato Sauce)\nPantry staples (plus one bell pepper) unite for this easy, filling, flavor-packed egg dish.\n'}]}
